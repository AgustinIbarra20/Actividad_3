# %% [markdown]
# <a href="https://colab.research.google.com/github/AgustinIbarra20/Actividad_3/blob/main/Actividad_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cc93cff8-817d-4e25-9680-da287aa11013" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc93cff8-817d-4e25-9680-da287aa11013">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#carga de un archivo csv sin ídices
df=pd.read_csv('Act2_1_Valores_nulos.csv')
df.head()
# Out:
#    Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0           0    01/01/2017                    27858.9
# 1           1    01/02/2017                    25994.2
# 2           2    01/03/2017                    27780.0
# 3           3    01/04/2017                    29134.3
# 4           4    01/05/2017                    27969.0
#
#    ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                    27477.3                 27858872.08   27591730.13
# 1                    25223.4                 25994200.17   25749179.40
# 2                    26334.3                 27780006.52   27472228.72
# 3                    27045.9                 29134272.22   28827479.49
# 4                    25631.9                 27969004.68   27569311.41
#
#    canales_on_line  ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 0       267141.956                27858872.08  1.023010e+07      6864575.384
# ...

# %%
#identificar valores nulos por columna
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos en ventas_precios_constantes
y=df['ventas_precios_constantes']
Limite_superior= y.mean() + 3*y.std()
Limite_inferior= y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 40022.90598479884
# Limite inferior permitido 12104.484784431932

# %%
#Encontramos outliers
outliers = df[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457               8.114070e+07  24935747.29      22143208.63
# 60      4819479.554               1.545171e+08  46962602.22      46053650.13
#
#     ...      almacen    panaderia       lacteos        carnes  \
# 42  ...  23393038.41  2630487.791  9.592798e+06  8.463266e+06
# 60  ...  37505172.62  4860317.680  1.610477e+07  1.740849e+07
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                    5.189425e+05
# ...

# %%
#obtenemos datos limpios
data_clean_ventas_precios_constantes = df[(y<=Limite_superior) & (y>=Limite_inferior)]
data_clean_ventas_precios_constantes
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(data_clean_ventas_precios_constantes['ventas_precios_constantes'])
plt.title('Outliers de ventas_precios_constantes')
plt.show() #dibujamos el diagrama

# %%
#Metodo applicando cuartiles. Encuentro cuartiles 0.25 y 0.75

y=df['salon_ventas']

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q2
iqr= percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print('Limite superior permitido', Limite_Superior_iqr)
print('Limite inferior permitido', Limite_Inferior_iqr)
# Out:
# Limite superior permitido 170440082.58499998
# Limite inferior permitido -32001350.254999995

# %%
#Encontramos outliers
outliers_iqr = df[(y>Limite_Superior_iqr) | (y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#obtenemos datos limpios
data_clean_salon_ventas = df[(y<=Limite_Superior_iqr) & (y>=Limite_Inferior_iqr)]
data_clean_salon_ventas
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(data_clean_salon_ventas['salon_ventas'])
plt.title('Outliers de salon_ventas')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos en ventas_precios_constantes
y=df['bebidas']
Limite_superior= y.mean() + 3*y.std()
Limite_inferior= y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 26469925.066235706
# Limite inferior permitido -8784324.280143397

# %%
#Encontramos outliers
outliers = df[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#obtenemos datos limpios
data_clean_bebidas = df[(y<=Limite_superior) & (y>=Limite_inferior)]
data_clean_bebidas
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(data_clean_bebidas['bebidas'])
plt.title('Outliers de bebidas')
plt.show() #dibujamos el diagrama

# %%
#Metodo applicando cuartiles. Encuentro cuartiles 0.25 y 0.75

y=df['panaderia']

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q2
iqr= percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print('Limite superior permitido', Limite_Superior_iqr)
print('Limite inferior permitido', Limite_Inferior_iqr)
# Out:
# Limite superior permitido 5344003.4675
# Limite inferior permitido -946571.9125000001

# %%
#Encontramos outliers
outliers_iqr = df[(y>Limite_Superior_iqr) | (y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# 62     4.661350e+05                168982502.3  51262080.99      47364363.88
# 63     4.144284e+06                177148082.8  53189998.68      50063972.79
# ...

# %%
#obtenemos datos limpios
data_clean_panaderia = df[(y<=Limite_Superior_iqr) & (y>=Limite_Inferior_iqr)]
data_clean_panaderia
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(data_clean_panaderia['panaderia'])
plt.title('Outliers de panaderia')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos en ventas_precios_constantes
y=df['otros']
Limite_superior= y.mean() + 3*y.std()
Limite_inferior= y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 15882529.280238539
# Limite inferior permitido -4292814.019315463

# %%
#Encontramos outliers
outliers = df[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#obtenemos datos limpios
data_clean_otros = df[(y<=Limite_superior) & (y>=Limite_inferior)]
data_clean_otros
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(data_clean_otros['otros'])
plt.title('Outliers de otros')
plt.show() #dibujamos el diagrama

# %%
#Convertir data frame a csv
data_clean_ventas_precios_constantes.to_csv('Act3_data_clean_ventas_precios_constantes.csv')
data_clean_salon_ventas.to_csv('Act3_data_clean_salon_ventas.csv')
data_clean_bebidas.to_csv('Act3_data_clean_bebidas.csv')
data_clean_panaderia.to_csv('Act3_data_clean_panaderia.csv')
data_clean_otros.to_csv('Act3_data_clean_otros.csv')

# %%
#descargar archivo
from google.colab import files

files.download('Act3_data_clean_ventas_precios_constantes.csv')
files.download('Act3_data_clean_salon_ventas.csv')
files.download('Act3_data_clean_bebidas.csv')
files.download('Act3_data_clean_panaderia.csv')
files.download('Act3_data_clean_otros.csv')
